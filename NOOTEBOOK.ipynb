# %%
import pandas as pd


df = pd.read_csv("bicicletas_compartidas_bogota.csv")

# %%
df.head()
# Out:
#   viaje_id         inicio_viaje       estacion_origen localidad_origen  \
# 0  V000671  2026-04-22 08:35:33      Plaza de Bolívar    La Candelaria
# 1  V002336  2026-03-26 20:39:41      Plaza de Bolívar    La Candelaria
# 2  V002504  2026-03-09 11:25:42  Parque de los Novios   Barrios Unidos
# 3  V002587  2026-04-29 04:04:46       Parque de la 93        Chapinero
# 4  V000820  2026-05-26 03:55:26                Zona G        Chapinero
#
#          estacion_destino localidad_destino  duracion_min  distancia_km  \
# 0    Universidades Centro     La Candelaria          13.8          4.14
# 1    Universidades Centro     La Candelaria          10.8          2.47
# 2  Hacienda Santa Bárbara           Usaquén           6.6          0.83
# 3         Parque de la 93         Chapinero           7.6          1.68
# 4         Parque Nacional          Santa Fe          16.6          2.89
#
#   tipo_bicicleta tipo_usuario          clima  temperatura_c  precipitacion_mm  \
# ...

# %%
df.shape
# Out:
# (3214, 14)

# %%
df.columns
# Out:
# Index(['viaje_id', 'inicio_viaje', 'estacion_origen', 'localidad_origen',
#        'estacion_destino', 'localidad_destino', 'duracion_min', 'distancia_km',
#        'tipo_bicicleta', 'tipo_usuario', 'clima', 'temperatura_c',
#        'precipitacion_mm', 'fin_de_semana'],
#       dtype='str')

# %%
df.describe()
# Out:
#        duracion_min  distancia_km  temperatura_c  precipitacion_mm
# count   3214.000000   3162.000000    3169.000000       3214.000000
# mean      14.231518      2.853033      16.647144          0.996235
# std        8.670122      1.698718       2.356015          2.459092
# min        0.500000      0.050000       8.000000          0.000000
# 25%        8.900000      1.710000      15.100000          0.000000
# 50%       12.500000      2.480000      16.600000          0.000000
# 75%       17.600000      3.580000      18.300000          0.150000
# max      180.000000     31.200000      24.900000         12.000000

# %%
df.dtypes
# Out:
# viaje_id                 str
# inicio_viaje             str
# estacion_origen          str
# localidad_origen         str
# estacion_destino         str
# localidad_destino        str
# duracion_min         float64
# distancia_km         float64
# tipo_bicicleta           str
# tipo_usuario             str
# clima                    str
# temperatura_c        float64
# precipitacion_mm     float64
# fin_de_semana            str
# dtype: object

# %%
df[["distancia_km","duracion_min"]].corr()
# Out:
#               distancia_km  duracion_min
# distancia_km      1.000000      0.721721
# duracion_min      0.721721      1.000000

# %%
d = df.sort_values("distancia_km",ascending=False)
d.head()
# Out:
#      viaje_id         inicio_viaje        estacion_origen localidad_origen  \
# 2089  V000844  2026-03-03 20:53:19        Parque Nacional         Santa Fe
# 1052  V002209  2026-05-11 09:21:29  Parque de los Hippies        Chapinero
# 404   V001732  2026-03-31 19:36:50              Calle 116          Usaquén
# 1952  V001332  2026-05-19 04:59:43              Las Aguas    La Candelaria
# 2300  V000108  2026-03-24 19:24:17              Unicentro          Usaquén
#
#           estacion_destino localidad_destino  duracion_min  distancia_km  \
# 2089            Las Nieves          Santa Fe           8.9         31.20
# 1052  Parque de los Novios    Barrios Unidos          22.3         27.50
# 404               Galerías       Teusaquillo          58.2         13.70
# 1952                   NaN         Chapinero          61.9         10.73
# 2300               Parkway       Teusaquillo          40.3         10.63
#
# ...

# %%
d = df.sort_values("duracion_min",ascending=False)
d
# Out:
#      viaje_id         inicio_viaje        estacion_origen localidad_origen  \
# 750   V002333  2026-04-05 19:05:51              Unicentro          Usaquén
# 2972  V000070  2026-03-28 09:21:27               Galerías      Teusaquillo
# 1567  V001789  2026-05-25 10:27:40  Parque de los Hippies        Chapinero
# 1268  V002082  2026-05-26 07:21:17               Calle 63        Chapinero
# 1952  V001332  2026-05-19 04:59:43              Las Aguas    La Candelaria
# ...       ...                  ...                    ...              ...
# 2785  V002008  2026-05-11 09:37:03   Universidad Nacional      Teusaquillo
# 2858  V001811  2026-05-31 05:17:25             San Felipe   Barrios Unidos
# 298   V000225  2026-05-27 18:30:18              Corferias      Teusaquillo
# 2875  V001859  2026-03-19 07:11:39   Universidades Centro    La Candelaria
# 1913  V000954  2026-05-21 20:07:30   Centro Internacional         Santa Fe
#
# ...

# %% [markdown]
# a) p = 0.7217
#
# b) Podemos afirmar que exiate una fuerte relación lineal poositiva entre ambas variables, lo que quiere decir que cuando aumentan la distacia del recorrido tambien aumenta el tiempo de desplazamiento.
#
# c ) No seria correcto afirmar esto, puesto que aunque hay una relacion lineal positiva muy fuerte no significa que exista una razon de causalidad  y simplemente puede ser una relacion espuria.
#
# d) Una correlacion alta no implica que necesariamente una mayor distancia tenga un mayor tiempo como por ejemplo los viajes con el id
# V001732 que tiene una distancia de 31.20 km tiene una duración de 8,9 min y en cambio el viaje v002209 que tiene una distancia de 27,5 km tiene un tiempo de 22,3 min, mucho mas alto que el anterior teniendo una distancia menor

# %%
df[["distancia_km","duracion_min"]].describe()
# Out:
#        distancia_km  duracion_min
# count   3162.000000   3214.000000
# mean       2.853033     14.231518
# std        1.698718      8.670122
# min        0.050000      0.500000
# 25%        1.710000      8.900000
# 50%        2.480000     12.500000
# 75%        3.580000     17.600000
# max       31.200000    180.000000

# %%
IQRDIS = 3.580000 - 1.710000
IQRDUR = 17.600000 - 8.900000

# %%
df.boxplot(column = "distancia_km")
# Out:
# <Axes: >

# %% [markdown]
# | Registro | Clasificacion        | Justificacion                                                                                                                                  |
# |----------|----------------------|------------------------------------------------------------------------------------------------------------------------------------------------|
# | 2089     | Problemante error    | Es un valor muy grande para la distancia y el trasporte Del cual se hizo uso                                                                   |
# | 1052     | Probablemente error  | Es un valor muy grande y se aleja demasiado de los datos como se puede ver, ademas de que no tiene sentido con los otros datos proporcionados  |
# | 404      | Ambiguo              | ES un valor grande para la informacion adicional que nos dan por lo cual no se sabe exactamente que podria ser                                 |
# | 1952     | probablemente error  | Es un valor grande para la informacion adicional que nos proporcionan                                                                          |
# | 2300     | Probablemente Error | Igual al anterior es un valor demasiado alto para la informacion adicional que nos proporcionan                                                |

# %%
df.boxplot(column = "duracion_min")
# Out:
# <Axes: >

# %% [markdown]
# | Registro | Clasificacion        | Justificacion                                                                                                                                         |
# |----------|----------------------|-------------------------------------------------------------------------------------------------------------------------------------------------------|
# | 750      | ambiguo              | Teniendo en cuenta el contexto de la ciudad es muy posible que se puedan presentar estos valores, sin embargo tocaria revisar el caso mas a fondo     |
# | 2972     | ambiguo              | Teniendo en cuenta el contexto de la ciudad es muy posible que se puedan presentar estos valores, sin embargo habria que revisar el caso mas a fondo  |
# | 1567     | Ambiguo              | Con el contexto de la ciudad en mente se puede presentar este valor sin embargo es recomendable revirsalo mas a profundidad                           |
# | 1268     | probablemente valido | Teniendo en cuenta el contexto de la ciudad es muy posible que se presenten estos valores                                                             |
# | 1952     | Probablemente valido | Teniendo encuenta el contexto de la ciudad es muy posible que encontremos valores como este.                                                          |

# %%
filas_borrar = [750,2972,1567,1268,1952,2089,1052,404,1952,2300]
new_datset = df.drop(filas_borrar)
new_datset
# Out:
#      viaje_id         inicio_viaje       estacion_origen localidad_origen  \
# 0     V000671  2026-04-22 08:35:33      Plaza de Bolívar    La Candelaria
# 1     V002336  2026-03-26 20:39:41      Plaza de Bolívar    La Candelaria
# 2     V002504  2026-03-09 11:25:42  Parque de los Novios   Barrios Unidos
# 3     V002587  2026-04-29 04:04:46       Parque de la 93        Chapinero
# 4     V000820  2026-05-26 03:55:26                Zona G        Chapinero
# ...       ...                  ...                   ...              ...
# 3209  V001604  2026-02-09 08:38:47  Centro Internacional         Santa Fe
# 3210  V002551  2026-03-21 15:54:26  Parque de los Novios   Barrios Unidos
# 3211  V000538  2026-04-20 20:31:42            San Felipe   Barrios Unidos
# 3212  V001221  2026-05-15 18:30:35               Parkway      Teusaquillo
# 3213  V000176  2026-05-23 19:24:26  Universidad Nacional      Teusaquillo
#
#             estacion_destino localidad_destino  duracion_min  distancia_km  \
# ...

# %%
new_datset[["distancia_km","duracion_min"]].corr()
# Out:
#               distancia_km  duracion_min
# distancia_km      1.000000      0.912077
# duracion_min      0.912077      1.000000

# %% [markdown]
# A) Aunque si presenta un aumento en la relacion que encontramos solo nos ayuda a rectificar algo que ya habiamos identificado anteriormente
#
# B) la relacion presente es mucho mas fuerte de lo que parecia ya que tuvo un aumento considerebla al excluir estos valores atipicos por lo cual tocaria revisar terceras variables antes de poder concluir que estas se relacionan directamente. sin embargo, hallamos que existe una relacion positiva entre estas.
#
# C)No ya que primero hay que identificar y profundizar en estos valores atipicos antes de tomar una desicion en caso de que sean erroneos estoy de acuerdo en solo presentar el ultimo resultado, sin embargo en caso contrario es mejor presentar ambos y enteder eso como afecta en otras variables ya que sabemos que al eliminar estos valores solo confirmamos que existe dicha relacion.

# %%
df["tipo_bicicleta"] = df["tipo_bicicleta"].str.replace("Eléctrica", "electrica")

# %%
df.groupby("tipo_bicicleta")["distancia_km"].mean()
# Out:
# tipo_bicicleta
# Mecánica     2.890151
# electrica    2.812424
# Name: distancia_km, dtype: float64

# %%
df.groupby("tipo_bicicleta")["duracion_min"].mean()
# Out:
# tipo_bicicleta
# Mecánica     15.382002
# electrica    12.974674
# Name: duracion_min, dtype: float64

# %%
df.groupby("tipo_bicicleta")["duracion_min"].median()
# Out:
# tipo_bicicleta
# Mecánica     13.55
# electrica    11.50
# Name: duracion_min, dtype: float64

# %%
df.groupby("tipo_bicicleta").size()
# Out:
# tipo_bicicleta
# Mecánica     1678
# electrica    1536
# dtype: int64

# %% [markdown]
# | Tipo de bicicleta | Número de viajes | Distancia promedio (km) | Duración promedio (min) | Duración mediana (min) |
# |-------------------|------------------|--------------------------|---------------------------|---------------------------|
# | Mecánica          | 1678             | 2.890151                 | 15.382002                  | 13.55                      |
# | Eléctrica         | 1536             | 2.812424                 | 12.974674                  | 11.50                      |

# %% [markdown]
# 4) Si por lo que vemos en la tabla las electricas tienen una duracion menor promedio teniendo una distancia muy similar (2,89km vs 2,81km), y en la mediana tenemos la misma tendencia con electricas que tienen menor duración.

# %%
df["clima"]= df["clima"].str.replace("Lluvia ligera","lluvia ligera")

# %%
df.groupby("clima").size()
# Out:
# clima
# Despejado        1337
# Lluvia            358
# Nublado          1059
# lluvia ligera     460
# dtype: int64

# %%
df.groupby("clima")["distancia_km"].mean()
# Out:
# clima
# Despejado        2.854924
# Lluvia           2.940600
# Nublado          2.804957
# lluvia ligera    2.889978
# Name: distancia_km, dtype: float64

# %%
df.groupby("clima")["duracion_min"].mean()
# Out:
# clima
# Despejado        14.272251
# Lluvia           14.310615
# Nublado          14.037205
# lluvia ligera    14.498913
# Name: duracion_min, dtype: float64

# %%
df.groupby("clima")["duracion_min"].median()
# Out:
# clima
# Despejado        12.50
# Lluvia           12.75
# Nublado          12.30
# lluvia ligera    12.90
# Name: duracion_min, dtype: float64

# %%
d = df.query("distancia_km >= 2 and distancia_km <= 4")

# %%
d.groupby("clima").size()
# Out:
# clima
# Despejado        607
# Lluvia           162
# Nublado          490
# lluvia ligera    212
# dtype: int64

# %%
d.groupby("clima")["distancia_km"].mean()
# Out:
# clima
# Despejado        2.826161
# Lluvia           2.866914
# Nublado          2.813286
# lluvia ligera    2.883160
# Name: distancia_km, dtype: float64

# %%
d.groupby("clima")["duracion_min"].mean()
# Out:
# clima
# Despejado        14.506590
# Lluvia           14.465432
# Nublado          14.524490
# lluvia ligera    14.433491
# Name: duracion_min, dtype: float64

# %%
d.groupby("clima")["duracion_min"].median()
# Out:
# clima
# Despejado        13.90
# Lluvia           13.85
# Nublado          13.65
# lluvia ligera    13.75
# Name: duracion_min, dtype: float64

# %% [markdown]
# 5.
# a)
# | Clima            | Número de viajes | Distancia promedio (km) | Duración promedio (min) | Duración mediana (min) |
# |-------------------|-------------------|---------------------------|---------------------------|---------------------------|
# | Despejado         | 1337              | 2.854924                  | 14.272251                  | 12.50                      |
# | Lluvia            | 358               | 2.940600                  | 14.310615                  | 12.75                      |
# | Lluvia ligera     | 460               | 2.889978                  | 14.498913                  | 12.90                      |
# | Nublado           | 1059              | 2.804957                  | 14.037205                  | 12.30                      |

# %% [markdown]
# b)
# | Clima            | Número de viajes | Distancia promedio (km) | Duración promedio (min) | Duración mediana (min) |
# |-------------------|-------------------|---------------------------|---------------------------|---------------------------|
# | Despejado         | 607               | 2.826161                  | 14.506590                  | 13.90                      |
# | Lluvia            | 162               | 2.866914                  | 14.465432                  | 13.85                      |
# | Lluvia ligera     | 212               | 2.883160                  | 14.433491                  | 13.75                      |
# | Nublado           | 490               | 2.813286                  | 14.524490                  | 13.65                      |

# %% [markdown]
# c)
# -Las variables no cambian mucho, la que  cambia es la cantidad de viajes cuando cambia el clima. Cuando es un clima lluvioso podemos apreciar que la cantidad de viajes disminuye considerablemente.
#
# -Porque en la tabla completa las duraciones si varian un poco mas entre climas, casi medio minuto de diferencia. Pero cuando filtro solo los viajes de 2 a 4 km, esa diferencia casi se borra. O sea que gran parte de lo que parecia culpa del clima en realidad era porque los viajes de cada clima tenian distancias distintas. Si comparamos todo junto sin fijar la distancia, se mezclan los dos efectos y parece que el clima pesa mas de lo que en verdad pesa.
#
# -Podría ser una variable de confusión, porque a mayor distancia el viaje dura más y quizás está relacionada con el clima. Pero cuando lo controlo por la distancia, las diferencias entre climas casi no cambian, así que su efecto parece ser mínimo.
#
# -No porque en la tabla no se reflejan estos resultados, vemos que todos tienen una duracion muy parecida y en la tabla general vemos que hay cambios pero no son por el clima, y lo que mas cambia por el clima es la cantidad de viajes.

# %% [markdown]
# Es importante reconocer que aunque hay varios outliders se pueden encontrar que la mayoria recorre distancias pequeñas en tiempos de corta duracion mejorando asi su movilidad, encontramos dos extremos interesentes en donde se recorrio casi 32 KM lo cual al analizarlo no tiene sentido y el otro caso fue una duracion de trayecto de 180 min que tocaria investigar mas por temas de movilidad en la ciudad. Encontramos una relacion directa entre el aumento del tiempo y la distacia en la mayoria de datos aun asi toca revisar variables terceras que puedan afectar y que no estan en la base de datos, para futuras investigaciones ¿cuales son las localidades con mayor tiempo de recorrido transcurrido?, por ultimo tomaria encuenta el clima para conocer como afecta el tiempo transcurrido
